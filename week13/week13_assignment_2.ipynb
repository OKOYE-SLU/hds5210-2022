# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
import pandas as pd
price = pd.read_csv('insulin.csv')

# %%
price
# Out:
#            country  avgCost  human  analog   rapid  rapidInt  short  shortInt  \
# 0    United States    98.70  85.21   99.94  119.36    107.31  87.20     95.05
# 1           Mexico    16.48   9.45   18.91   14.30     15.92  12.21     16.87
# 2            Japan    14.40  14.30   14.41   13.49     13.01  15.54     13.34
# 3           Turkey     2.64   1.97    2.66    2.39      2.63   2.14      1.74
# 4          Germany    11.00   7.13   12.60   12.02     10.57   7.06      7.20
# 5   United Kingdom     7.52   5.13    8.09    7.22      7.00   6.24      5.05
# 6           France     9.08   9.16    9.02    7.95      6.92  19.19      7.08
# 7            Italy    10.03   6.88   10.07    7.69      7.25   6.34     10.36
# 8            Spain     9.04   6.04    9.32    7.37      7.39   6.85      5.78
# 9           Poland     5.28   4.27    6.30    5.53      5.98   4.22      4.31
# 10          Canada    12.00   7.11   12.99    9.88      8.96   7.10      7.32
# ...

# %%
price.shape
# Out:
# (32, 10)

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
price.value_counts()
# Out:
# country         avgCost  human  analog  rapid   rapidInt  short  shortInt  intm   long
# United States   98.70    85.21  99.94   119.36  107.31    87.20  95.05     73.56  88.10    1
# Japan           14.40    14.30  14.41   13.49   13.01     15.54  13.34     13.80  15.90    1
# Austria         7.92     6.63   8.17    7.17    7.09      6.96   6.60      6.58   12.61    1
# Belgium         8.30     5.43   8.92    7.86    7.29      5.73   5.70      4.86   11.26    1
# Canada          12.00    7.11   12.99   9.88    8.96      7.10   7.32      7.02   15.77    1
# Chile           21.48    17.77  21.99   15.01   14.94     16.57  25.47     17.92  26.19    1
# Czech Republic  8.18     4.69   9.11    7.48    6.94      4.69   4.70      4.72   11.68    1
# France          9.08     9.16   9.02    7.95    6.92      19.19  7.08      7.62   10.36    1
# Germany         11.00    7.13   12.60   12.02   10.57     7.06   7.20      7.23   13.46    1
# ...

# %%
price['avgCost'].value_counts()
# Out:
# 21.48    1
# 6.14     1
# 12.00    1
# 8.94     1
# 2.64     1
# 6.94     1
# 14.40    1
# 8.18     1
# 9.61     1
# 8.39     1
# 16.48    1
# 8.03     1
# 6.91     1
# 12.36    1
# 7.71     1
# 7.79     1
# 5.28     1
# 8.30     1
# 9.98     1
# 8.89     1
# 10.03    1
# 7.43     1
# 7.92     1
# 9.08     1
# 7.89     1
# 7.52     1
# 9.85     1
# 98.70    1
# 10.15    1
# 9.04     1
# 8.65     1
# 11.00    1
# Name: avgCost, dtype: int64

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
column = [column for column in price.columns if price[column].nunique() == 1]

# %%
column
# Out:
# []

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
import matplotlib.pyplot as plt
new_data = price.groupby('country').agg({'avgCost':'mean'})

# %%
new_data.hist(figsize=(11,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe6edc29048>]],
#       dtype=object)

# %%
new_data
# Out:
#                 avgCost
# country
# Australia          6.94
# Austria            7.92
# Belgium            8.30
# Canada            12.00
# Chile             21.48
# Czech Republic     8.18
# Estonia            9.61
# Finland            8.94
# France             9.08
# Germany           11.00
# Greece             8.65
# Hungary            6.14
# Ireland            9.85
# Italy             10.03
# Japan             14.40
# Latvia             8.39
# Lithuania          7.89
# Luxembourg        10.15
# Mexico            16.48
# Netherlands        9.98
# New Zealand        8.89
# Norway             7.79
# Poland             5.28
# Portugal           8.03
# Slovakia           6.91
# Slovenia           7.43
# Spain              9.04
# Sweden             7.71
# Switzerland       12.36
# Turkey             2.64
# United Kingdom     7.52
# United States     98.70

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
new_data = price.groupby('country').agg({'avgCost':'mean'})

# %%
new_data
# Out:
#                 avgCost
# country
# Australia          6.94
# Austria            7.92
# Belgium            8.30
# Canada            12.00
# Chile             21.48
# Czech Republic     8.18
# Estonia            9.61
# Finland            8.94
# France             9.08
# Germany           11.00
# Greece             8.65
# Hungary            6.14
# Ireland            9.85
# Italy             10.03
# Japan             14.40
# Latvia             8.39
# Lithuania          7.89
# Luxembourg        10.15
# Mexico            16.48
# Netherlands        9.98
# New Zealand        8.89
# Norway             7.79
# Poland             5.28
# Portugal           8.03
# Slovakia           6.91
# Slovenia           7.43
# Spain              9.04
# Sweden             7.71
# Switzerland       12.36
# Turkey             2.64
# United Kingdom     7.52
# United States     98.70

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# Submit your work as usual.
